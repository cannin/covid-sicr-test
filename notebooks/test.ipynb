# %% [markdown]
# # Purpose
#
# This Jupyter notebook runs commands found is the test.sh file of the root directory

# %% [markdown]
# # Change Working Directory

# %%
# %cd /home/jovyan/covid-sicr
# Out:
# /home/jovyan/covid-sicr

# %% [markdown]
# # Get Data

# %%
# !python scripts/get-data.py
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)Getting data from jhu...
# Could not download data for recovered, US
# JHU has 164 countries with good data.
# Countries: 100%|██████████████████████████████| 164/164 [00:01<00:00, 83.03it/s]
# Getting data from covid-tracking...
# US States: 100%|████████████████████████████████| 56/56 [00:00<00:00, 84.84it/s]
# COVID Tracking had recovery data for AK,AL,AR,AZ,CO,CT,DC,DE,GU,HI,IA,ID,IN,KS,KY,LA,MD,ME,MI,MN,MS,MT,NC,ND,NE,NH,NJ,NM,NV,NY,OK,OR,PA,RI,SC,SD,TN,TX,UT,VA,VI,VT,WI,WV,WY
# COVID Tracking has no recovery data for AS,CA,FL,GA,IL,MA,MO,MP,OH,PR,WA
# Data now available at /home/jovyan/covid-sicr/data

# %% [markdown]
# # Run Model

# %%
# !python scripts/run.py SICRLMQC2R --n-warm=5 --n-iter=50
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)Using default values to initialize fit
#
# Gradient evaluation took 0.003443 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 34.43 seconds.
# Adjust your expectations accordingly!
#
#
# WARNING: No variance estimation is
#          performed for num_warmup < 20
#
#
# Gradient evaluation took 0.00405 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 40.5 seconds.
# Adjust your expectations accordingly!
#
#
# WARNING: No variance estimation is
#          performed for num_warmup < 20
#
#
# Gradient evaluation took 0.004022 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 40.22 seconds.
# Adjust your expectations accordingly!
#
#
# WARNING: No variance estimation is
#          performed for num_warmup < 20
#
#
# Gradient evaluation took 0.004113 seconds
# ...

# %% [markdown]
# # Visualize (Not Working)

# %%
# Not working
#!python scripts/visualize.py

# %% [markdown]
# # Get N Data for Make Tables

# %%
# !python scripts/get-n-data.py
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)

# %% [markdown]
# # Make Tables

# %%
# !python scripts/make-tables.py
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)There are 2 combinations of models and ROIs
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 10.98it/s]
